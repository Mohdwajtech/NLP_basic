# %%
from gensim.models import Word2Vec, KeyedVectors
from sklearn.decomposition import PCA
model = KeyedVectors.load_word2vec_format('../../Downloads/GoogleNews-vectors-negative300.bin', binary=True)

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
import numpy as np

# %%
model.most_similar('good',topn=20)
# Out:
# [('great', 0.7291510105133057),
#  ('bad', 0.7190051078796387),
#  ('terrific', 0.6889115571975708),
#  ('decent', 0.6837348341941833),
#  ('nice', 0.6836092472076416),
#  ('excellent', 0.644292950630188),
#  ('fantastic', 0.6407778263092041),
#  ('better', 0.6120728850364685),
#  ('solid', 0.5806034803390503),
#  ('lousy', 0.576420247554779),
#  ('wonderful', 0.5726117491722107),
#  ('terrible', 0.5602042078971863),
#  ('Good', 0.5586156249046326),
#  ('tough', 0.5585317015647888),
#  ('best', 0.546719491481781),
#  ('alright', 0.541784942150116),
#  ('perfect', 0.5401014089584351),
#  ('strong', 0.5392314791679382),
#  ('pretty_darn', 0.5339667201042175),
#  ('really', 0.5286920070648193)]

# %% [markdown]
# ### Representing a sentence using word embeddings

# %%
sent1 = 'I am happy'
sent2 = 'I am sad'
sent3 = 'Lion is the king'

# %%
sent1_vect = model['I'] + model['am'] + model['happy']
sent2_vect = model['I'] + model['am'] + model['sad']
sent3_vect = model['Lion'] + model['is'] + model['the'] + model['king']

# %%
cosine_similarity(np.array([sent1_vect]),np.array([sent2_vect]))
# Out:
# array([[0.900164]], dtype=float32)

# %%
cosine_similarity(np.array([sent1_vect]),np.array([sent3_vect]))
# Out:
# array([[0.25262803]], dtype=float32)

# %%
cosine_similarity(np.array([sent2_vect]),np.array([sent3_vect]))
# Out:
# array([[0.25343737]], dtype=float32)

# %%
import spacy

nlp = spacy.load("en_core_web_md")  # make sure to use larger package!

doc1 = nlp("I am happy")
doc2 = nlp("Lion is the king")

# Similarity of two documents
print(doc1, "<->", doc2, doc1.similarity(doc2))
# Out:
# I am happy <-> Lion is the king 0.4673521773277266

# %%
doc1.vector
# Out:
# array([-2.93629374e-02,  1.72966123e-01, -1.37989148e-01, -1.73202947e-01,
#         5.99201843e-02,  1.85221821e-01,  3.27481180e-02, -2.46253729e-01,
#        -7.02806097e-03,  2.17297816e+00, -4.12840247e-01,  1.17184751e-01,
#        -2.43414976e-02, -1.16042867e-01, -4.54685166e-02,  5.08753806e-02,
#        -6.12612516e-02,  1.16719747e+00, -1.60679370e-01, -9.42105707e-03,
#         8.52583721e-02, -6.81634471e-02,  2.14425009e-03, -3.40435617e-02,
#        -1.31085254e-02,  5.08599393e-02, -1.10305265e-01,  1.29563371e-02,
#         2.39071354e-01,  7.52802715e-02, -5.88573180e-02, -8.31807256e-02,
#         9.97276232e-02,  3.49679291e-02,  3.18168774e-02,  1.58905629e-02,
#         8.60286951e-02,  1.87955350e-02, -1.85476452e-01,  1.76024623e-02,
#         4.69134562e-03, -1.79205667e-02,  7.09676892e-02,  4.49075997e-02,
#        -7.81192482e-02,  2.12777808e-01, -7.79069364e-02, -1.01418056e-01,
#         9.23099965e-02, -1.23335935e-01, -7.69099370e-02,  7.70936813e-03,
#        -7.59949982e-02, -1.54609740e-01, -3.20506468e-03, -3.24244983e-03,
#        -7.34087601e-02, -2.05853924e-01,  2.13939101e-01, -1.46311849e-01,
#        -1.54399320e-01, -2.37559751e-01,  8.28944147e-03,  9.67292264e-02,
#        -4.57461886e-02, -1.12616584e-01,  1.04999943e-02,  1.40913650e-01,
#        -3.39934155e-02,  2.01050758e-01, -2.87678353e-02,  8.76877606e-02,
#         1.07119560e-01,  3.02571747e-02,  2.31351867e-01,  1.54542744e-01,
#         7.35138729e-02,  2.20298730e-02, -9.20588821e-02,  2.86884010e-01,
#         6.89271837e-02,  1.01701677e-01, -1.72919985e-02,  2.82670949e-02,
#        -3.72956507e-03, -2.63170958e-01,  2.70482413e-02, -4.04099554e-01,
#         1.25367448e-01,  3.48663069e-02, -1.48269370e-01, -4.81148101e-02,
#        -2.26517186e-01,  9.18783695e-02,  2.08248198e-01, -1.07405946e-01,
#         9.50994939e-02,  6.77162968e-03, -1.13689184e-01, -5.20397462e-02,
#        -1.03843756e-01,  1.33913428e-01,  5.17555289e-02,  5.52089885e-02,
#         1.06885999e-01, -6.33605957e-01,  5.35690673e-02, -1.37874544e-01,
#         2.28086133e-02, -9.48968157e-02,  7.43564665e-02, -2.89935946e-01,
#         1.64570302e-01, -2.61620909e-01,  3.52743641e-02, -1.56815331e-02,
#         3.04798223e-02,  2.56008692e-02, -7.57126212e-02, -8.17524642e-02,
#         9.37343836e-02, -4.39954959e-02,  1.34376317e-01, -1.37709066e-01,
#         1.59311056e-01,  1.73136771e-01,  4.89334352e-02, -1.30563214e-01,
#         9.57128108e-02, -6.99250214e-03,  8.55228528e-02, -1.01714507e-02,
#        -1.85597360e-01,  3.64812538e-02,  2.06743687e-01,  3.56959403e-02,
#        -7.96763599e-02,  3.80962784e-03,  3.46831679e-02,  7.01679364e-02,
#        -1.27071118e+00,  3.57008129e-02,  2.88423985e-01, -3.06300484e-02,
#         1.49605619e-02,  7.73551315e-02, -2.79344916e-01,  9.46996734e-05,
#        -1.22263446e-01, -1.86174259e-01, -1.88131258e-01,  4.13641259e-02,
#        -2.67822202e-03,  1.31217539e-02, -8.41589794e-02, -5.57554699e-03,
#         9.18518566e-03,  4.04904373e-02,  2.94233169e-02, -1.25563905e-01,
#         1.85999140e-01, -6.15850054e-02,  8.64686966e-02, -9.45009366e-02,
#        -1.85212120e-01,  5.03256284e-02, -3.49979550e-02, -9.80415121e-02,
#         1.15253605e-01, -4.64411862e-02, -1.44380689e-01, -3.58038172e-02,
#        -9.89571959e-02, -8.51523131e-02, -9.06184595e-03,  1.30588472e-01,
#        -1.44962296e-01,  1.54068172e-02, -7.38760680e-02,  4.68657538e-02,
#         1.06879838e-01,  3.70551273e-02, -1.31388053e-01, -3.51816416e-02,
#        -2.79323589e-02, -3.24522890e-02, -7.74990618e-02, -1.02167815e-01,
#         1.85122848e-01, -2.98966207e-02,  1.37353092e-02,  6.22745603e-02,
#         2.10580975e-03, -4.90348265e-02,  6.56237546e-03,  1.99493766e-01,
#         1.83062535e-03, -1.04705505e-01, -7.07340986e-02,  3.42037529e-03,
#        -2.36143470e-02, -2.01033920e-01,  8.39307532e-02,  8.98275301e-02,
#         2.10301384e-01, -1.05264327e-02,  1.04368009e-01, -4.08948399e-02,
#         3.10464203e-03, -3.32790576e-02, -1.18646711e-01, -1.37976184e-01,
#        -4.31118123e-02, -2.20992818e-01, -3.51693295e-03, -3.76680605e-02,
#        -2.48846933e-02, -9.47883800e-02, -2.23208621e-01,  6.26335666e-02,
#         7.97811896e-02,  6.93801418e-02,  1.28787225e-02, -3.65481824e-02,
#         5.30606955e-02,  8.35108683e-02,  9.56720561e-02,  7.35871866e-02,
#         5.73087558e-02,  5.23172691e-02, -1.24362752e-01,  1.77344363e-02,
#         5.26488386e-02,  9.93436389e-03, -8.89265612e-02, -1.19616412e-01,
#        -1.98365018e-01, -9.97211933e-02, -9.69280452e-02,  1.46978721e-02,
#         7.51267821e-02,  7.02403188e-02,  2.38388106e-02,  1.55830011e-01,
#         4.84794341e-02, -2.34806135e-01, -1.12321228e-02,  1.39292762e-01,
#        -1.00179553e-01,  2.45480388e-01,  2.30931506e-01, -4.17712517e-03,
#         2.64700651e-02, -8.44901204e-02,  2.41359174e-01,  1.91975571e-03,
#         1.33550195e-02, -3.59923728e-02, -7.34191388e-02, -6.32434413e-02,
#         2.83636212e-01,  3.12598884e-01, -2.18072534e-02,  1.67058304e-01,
#        -1.81345135e-01, -2.65938222e-01, -4.30066288e-02, -5.69537748e-03,
#         3.17139089e-01,  1.72276020e-01, -9.03687403e-02, -5.33074401e-02,
#        -1.21508770e-01, -6.55099973e-02,  9.41268727e-03,  4.10599224e-02,
#         3.40363421e-02, -2.13435628e-02, -7.13868067e-02,  2.31698126e-01,
#         2.55437940e-01, -2.56873760e-02, -2.62818709e-02, -1.10183246e-01,
#        -1.28456838e-02, -9.05686244e-02,  1.60585195e-01, -1.65699512e-01,
#         1.13712668e-01,  7.12468177e-02, -1.06988057e-01,  4.82015647e-02,
#        -5.99631406e-02, -7.09710568e-02,  1.18143804e-01, -9.90505517e-02,
#        -1.00139879e-01,  8.11725035e-02, -9.78213102e-02,  1.30748063e-01],
#       dtype=float32)
