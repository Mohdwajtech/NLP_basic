# %%
#!pip install librosa

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

# %%
y, sr = librosa.load('00b01445_nohash_0.wav')

# %%
#waveform
y
# Out:
# array([ 0.00136016,  0.00271502, -0.00157604, ..., -0.00660018,
#         0.00084331,  0.00342824], dtype=float32)

# %%
#sampling rate
sr
# Out:
# 22050

# %%
y, sr = librosa.load('00b01445_nohash_0.wav', sr=25000)
sr
# Out:
# 25000

# %%
plt.plot(y);

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref = np.max)

# %%
librosa.display.specshow(D)
